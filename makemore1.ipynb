# %% [markdown]
# <a href="https://colab.research.google.com/github/Maverick-Ansh/Karpathy-_neural_networks/blob/main/makemore1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Use the path you copied from the sidebar
path = '/content/drive/MyDrive/makemore/names.txt'

words = open(path, 'r').read().splitlines()

# Quick check to see if it worked
print(f"Loaded {len(words)} names.")
print("the words are kinda",words[:7])
# Out:
# Loaded 32033 names.
# the words are kinda ['emma', 'olivia', 'ava', 'isabella', 'sophia', 'charlotte', 'mia']

# %%
len(words)
wordlength=set(words)
print(len(wordlength))
# Out:
# 29494

# %%
print(min(len(w) for w in words))
print(max(len(w) for w in words ))
# Out:
# 2
# 15

# %%
#will start building first the bigram model
#we are gonna get the start and ending so that we can count and maybe change the weights of it
for word in words[:6]:
  chs=['<S>']+list(word)+['<E>']
  for ch1,ch2 in zip(chs,chs[1:]):
    print(ch1,ch2)
# Out:
# <S> e
# e m
# m m
# m a
# a <E>
# <S> o
# o l
# l i
# i v
# v i
# i a
# a <E>
# <S> a
# a v
# v a
# a <E>
# <S> i
# i s
# s a
# a b
# b e
# e l
# l l
# l a
# a <E>
# <S> s
# s o
# o p
# p h
# h i
# i a
# a <E>
# <S> c
# c h
# h a
# a r
# r l
# l o
# o t
# t t
# t e
# e <E>
